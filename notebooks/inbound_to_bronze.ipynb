// %% [markdown]
// Conferindo se os dados foram montadose se temos acesso a pasta inbound

// %%
%python
dbutils.fs.ls("/mnt/dados/inbound")

// %% [markdown]
// ## **Lendo os dados na camada de inbound**

// %%
val path = "dbfs:/mnt/dados/inbound/dados_brutos_imoveis.json"
val dados = spark.read.json(path)

// %%
display(dados)

// %% [markdown]
// ## Removendo colunas

// %%
val dados_anauncio = dados.drop("imagens", "usuario")
display(dados_anauncio)

// %% [markdown]
// ## Criando coluna de identificação

// %%
import org.apache.spark.sql.functions.col

// %%
val df_bronze = dados_anauncio.withColumn("id", col("anuncio.id"))
display(df_bronze)

// %%
val path = "dbfs:/mnt/dados/bronze/dataset_imoveis"
df_bronze.write.format("delta").mode(SaveMode.Overwrite).save(path)
